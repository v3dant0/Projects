# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# # Cleaning Data

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # Analyzing Columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
for column in df.columns :
    print(column, ":", df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].mean()
# Out:
# 9333.859852635065

# %% [markdown]
# # Analyzing Genders

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %% [markdown]
# Total male spenders

# %%
len(df[df['Gender'] == 'M'])
# Out:
# 405380

# %% [markdown]
# Total Female Spenders

# %%
len(df[df['Gender'] == 'F'])
# Out:
# 132197

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind = "pie", autopct = "%.2f", title = 'Gender Ratio')
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# Total money spent by Male and Female Genders

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind = 'pie', autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# Avg money spent by male and female genders on per product

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind = 'pie', autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# # Analysing age and Maritial status

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size().plot(kind = "bar", title = "Age Distribution")
# Out:
# <Axes: title={'center': 'Age Distribution'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].sum().plot(kind = "bar", figsize = (8,6), title = "Amount spent by age")
# Out:
# <Axes: title={'center': 'Amount spent by age'}, xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind = "pie", autopct = "%.2f", figsize = (8,6), title = "Average Amount spent by age")
# Out:
# <Axes: title={'center': 'Average Amount spent by age'}, ylabel='Purchase'>

# %% [markdown]
# How many people are married/Unmarried

# %%
df.groupby('Marital_Status').size().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: >

# %% [markdown]
# # Analysing city

# %%
df.groupby('City_Category').size().plot(kind = 'pie', autopct = "%.2f", title = "Total Products purchased from each city")
# Out:
# <Axes: title={'center': 'Total Products purchased from each city'}>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind = 'pie', autopct = "%.2f", title = "Total money spent by each City")
# Out:
# <Axes: title={'center': 'Total money spent by each City'}, ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind = 'pie', autopct = "%.2f", title = "Avg money spent by a city resident on a product")
# Out:
# <Axes: title={'center': 'Avg money spent by a city resident on a product'}, ylabel='Purchase'>

# %% [markdown]
# # Stay in current city Analysis

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: >

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %% [markdown]
# # Occupation

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar', title = "Total products purchased as per occupation")
# Out:
# <Axes: title={'center': 'Total products purchased as per occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind = 'bar', title = 'Total money spent by a particular occupation')
# Out:
# <Axes: title={'center': 'Total money spent by a particular occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind = 'bar', title = 'Avg money spent by a particular occupation on a particular product')
# Out:
# <Axes: title={'center': 'Avg money spent by a particular occupation on a particular product'}, xlabel='Occupation'>

# %% [markdown]
# # Product Category

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# # Product ID

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind = 'bar', title = "Hot selling products")
# Out:
# <Axes: title={'center': 'Hot selling products'}, xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind = 'bar', title = "Most expensive Products")
# Out:
# <Axes: title={'center': 'Most expensive Products'}, xlabel='Product_ID'>

# %% [markdown]
# # Multivariate Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x = "Age", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = "Gender", hue = "Age", data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = "Marital_Status", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = "City_Category", hue = "Age", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = "City_Category", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df['Marital_Status'] = df['Marital_Status'].astype(str)
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # Combining Gender and Marital status

# %%
l = []
for i in range(len(df)):
    l.append(df['Gender'][i] + "_" + str(df['Marital_Status'][i]))
    
df['MaritalGender'] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase  \
# 0                          2              0                   3      8370
# 1                          2              0                   1     15200
# 2                          2              0                  12      1422
# 3                          2              0                  12      1057
# 4                         4+              0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
df.groupby('MaritalGender').size().plot(kind = "bar")
# Out:
# <Axes: xlabel='MaritalGender'>

# %%
sns.countplot(x = 'Age', hue = 'MaritalGender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'MaritalGender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'MaritalGender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>
